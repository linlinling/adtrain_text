# %%
#baseline TextCNN
# !python run.py --model TextCNN
# Out:
# Loading data...
# Vocab size: 4762
# 180000it [00:03, 50054.16it/s]
# 10000it [00:00, 71004.93it/s]
# 10000it [00:00, 67210.16it/s]
# Time usage: 0:00:04
# model.parameters <bound method Module.parameters of TextCNN(
#   (embedding): Embedding(4762, 300)
#   (convs): ModuleList(
#     (0): Conv2d(1, 256, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 256, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 256, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=768, out_features=10, bias=True)
# )>
# Epoch [1/20]
# Iter:      0,  Train Loss:   2.3,  Train Acc:  8.59%,  Val Loss:   2.7,  Val Acc: 10.06%,  Time: 0:00:15 *
# Iter:    100,  Train Loss:  0.78,  Train Acc: 74.22%,  Val Loss:  0.69,  Val Acc: 79.02%,  Time: 0:01:18 *
# Iter:    200,  Train Loss:  0.75,  Train Acc: 74.22%,  Val Loss:  0.55,  Val Acc: 83.25%,  Time: 0:02:17 *
# ...

# %%
# TextCNN + PGD
# !python run.py --model TextCNN --adv PGD
# Out:
# Loading data...
# Vocab size: 4762
# 180000it [00:02, 66272.98it/s]
# 10000it [00:00, 62624.08it/s]
# 10000it [00:00, 65448.87it/s]
# Time usage: 0:00:03
# model.parameters <bound method Module.parameters of TextCNN(
#   (embedding): Embedding(4762, 300)
#   (convs): ModuleList(
#     (0): Conv2d(1, 256, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 256, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 256, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=768, out_features=10, bias=True)
# )>
# Epoch [1/20]
# Iter:      0,  Train Loss:   2.3,  Train Acc: 10.16%,  Val Loss:   2.8,  Val Acc: 14.41%,  Time: 0:00:14 *
# Iter:    100,  Train Loss:   0.8,  Train Acc: 69.53%,  Val Loss:  0.67,  Val Acc: 78.98%,  Time: 0:03:49 *
# Iter:    200,  Train Loss:  0.76,  Train Acc: 75.78%,  Val Loss:  0.54,  Val Acc: 83.29%,  Time: 0:06:58 *
# ...

# %%
# TextCNN + Free
# !python run.py --model TextCNN --adv FreeAT
# Out:
# Loading data...
# Vocab size: 4762
# 180000it [00:02, 66287.19it/s]
# 10000it [00:00, 72862.94it/s]
# 10000it [00:00, 71747.30it/s]
# Time usage: 0:00:03
# model.parameters <bound method Module.parameters of TextCNN(
#   (embedding): Embedding(4762, 300)
#   (convs): ModuleList(
#     (0): Conv2d(1, 256, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 256, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 256, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=768, out_features=10, bias=True)
# )>
# Epoch [1/20]
# Iter:      0,  Train Loss:   2.2,  Train Acc: 17.19%,  Val Loss:   2.3,  Val Acc: 25.20%,  Time: 0:00:13 *
# Iter:    100,  Train Loss:  0.67,  Train Acc: 75.00%,  Val Loss:  0.59,  Val Acc: 81.75%,  Time: 0:02:50 *
# Iter:    200,  Train Loss:  0.73,  Train Acc: 76.56%,  Val Loss:  0.55,  Val Acc: 83.40%,  Time: 0:05:33 *
# ...

# %%
# TextCNN + FGSM
# !python run.py --model TextCNN --adv FGSM
# Out:
# Loading data...
# Vocab size: 4762
# 180000it [00:02, 67910.85it/s]
# 10000it [00:00, 74507.92it/s]
# 10000it [00:00, 80478.92it/s]
# Time usage: 0:00:03
# model.parameters <bound method Module.parameters of TextCNN(
#   (embedding): Embedding(4762, 300)
#   (convs): ModuleList(
#     (0): Conv2d(1, 256, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 256, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 256, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=768, out_features=10, bias=True)
# )>
# Epoch [1/20]
# Iter:      0,  Train Loss:   2.5,  Train Acc:  0.00%,  Val Loss:   2.8,  Val Acc: 10.38%,  Time: 0:00:13 *
# Iter:    100,  Train Loss:   1.9,  Train Acc: 40.62%,  Val Loss:  0.97,  Val Acc: 71.90%,  Time: 0:02:03 *
# Iter:    200,  Train Loss:   1.8,  Train Acc: 47.66%,  Val Loss:  0.78,  Val Acc: 78.32%,  Time: 0:03:49 *
# ...
